# %%
import pandas as pd

DATA_PATH = "../../data/" # Adjust this to your relative path to the datasets

# %%
corpus_df = pd.read_csv(DATA_PATH + "process_behavior_corpus.csv")
T_SAD_df = pd.read_csv(DATA_PATH + "T_SAD.csv")
A_SAD_df = pd.read_csv(DATA_PATH + "A_SAD.csv")
S_NAP_df = pd.read_csv(DATA_PATH + "S_NAP.csv")

# %%
T_SAD_df
# Out:
#                                 model_id                       revision_id  \
# 0       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 1       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 2       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 3       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 4       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# ...                                  ...                               ...
# 291246  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 291247  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 291248  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 291249  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 291250  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
#
#                                                     trace  \
# 0       ['Select necessary work equipment', 'Add perso...
# 1       ['Add personal data', 'Set up access rights, h...
# 2       ['Add personal data', 'Select necessary work e...
# 3       ['Select necessary work equipment', 'Add perso...
# 4       ['Select necessary work equipment', 'Add perso...
# ...                                                   ...
# 291246  ['Create purchase request', 'Place purchase or...
# 291247  ['Place purchase order', 'Create purchase requ...
# 291248  ['Create purchase request', 'Place purchase or...
# 291249  ['Create purchase request', 'Place purchase or...
# 291250  ['Create purchase request', 'Place purchase or...
#
#                                                     label  \
# 0       ['Select necessary work equipment', 'Add perso...
# 1       ['Set up access rights, hardware and software'...
# 2                                                   False
# 3       ['Select necessary work equipment', 'Add perso...
# 4       ['Select necessary work equipment', 'Add perso...
# ...                                                   ...
# 291246               ['Receive payment', 'Receive goods']
# 291247  ['Place purchase order', 'Create purchase requ...
# 291248                                              False
# 291249               ['Receive payment', 'Receive goods']
# 291250                                              False
#
#                                         unique_activities  anomalous  \
# 0       {'Set up access rights, hardware and software'...       True
# 1       {'Set up access rights, hardware and software'...       True
# 2       {'Set up access rights, hardware and software'...      False
# 3       {'Set up access rights, hardware and software'...       True
# 4       {'Set up access rights, hardware and software'...       True
# ...                                                   ...        ...
# 291246  {'Receive goods', 'Receive payment', 'Place pu...       True
# 291247  {'Receive goods', 'Receive payment', 'Place pu...       True
# 291248  {'Receive goods', 'Receive payment', 'Place pu...      False
# 291249  {'Receive goods', 'Receive payment', 'Place pu...       True
# 291250  {'Receive goods', 'Receive payment', 'Place pu...      False
#
#                                                        id
# 0       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 1       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 2       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 3       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 4       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# ...                                                   ...
# 291246  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 291247  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 291248  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 291249  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 291250  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
#
# [291251 rows x 7 columns]

# %%
A_SAD_df
# Out:
#                                 model_id                       revision_id  \
# 0       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 1       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 2       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 3       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 4       e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# ...                                  ...                               ...
# 316303  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 316304  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 316305  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 316306  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 316307  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
#
#         out_of_order                                  unique_activities  \
# 0               True  {'Set up access rights, hardware and software'...
# 1              False  {'Set up access rights, hardware and software'...
# 2              False  {'Set up access rights, hardware and software'...
# 3               True  {'Set up access rights, hardware and software'...
# 4               True  {'Set up access rights, hardware and software'...
# ...              ...                                                ...
# 316303          True  {'Receive goods', 'Receive payment', 'Place pu...
# 316304          True  {'Receive goods', 'Receive payment', 'Place pu...
# 316305         False  {'Receive goods', 'Receive payment', 'Place pu...
# 316306         False  {'Receive goods', 'Receive payment', 'Place pu...
# 316307         False  {'Receive goods', 'Receive payment', 'Place pu...
#
#                                        eventually_follows  \
# 0         ('Procure work equipment', 'Add personal data')
# 1       ('Set up access rights, hardware and software'...
# 2       ('Select necessary work equipment', 'Set up ac...
# 3       ('Procure work equipment', 'Select necessary w...
# 4       ('Set up access rights, hardware and software'...
# ...                                                   ...
# 316303               ('Receive payment', 'Receive goods')
# 316304       ('Receive goods', 'Create purchase request')
# 316305       ('Create purchase request', 'Receive goods')
# 316306               ('Receive goods', 'Receive payment')
# 316307          ('Place purchase order', 'Receive goods')
#
#                                                        id
# 0       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 1       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 2       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 3       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 4       e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# ...                                                   ...
# 316303  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 316304  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 316305  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 316306  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 316307  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
#
# [316308 rows x 6 columns]

# %%
S_NAP_df
# Out:
#                                  model_id                       revision_id  \
# 0        e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 1        e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 2        e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 3        e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 4        e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# ...                                   ...                               ...
# 1289076  1e07277a2ff0486cba1cd100be7b4a59  92f009351a754acba9ae871f4a1f22c6
# 1289077  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 1289078  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 1289079  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
# 1289080  1e0d27c5c47f486f8b90cd517bf9449d  ae7a74f9ae4a4b5fad9399b3dc19a97b
#
#                                                      trace  \
# 0        ['Add personal data', 'Select necessary work e...
# 1        ['Add personal data', 'Select necessary work e...
# 2        ['Add personal data', 'Select necessary work e...
# 3        ['Add personal data', 'Select necessary work e...
# 4        ['Add personal data', 'Select necessary work e...
# ...                                                    ...
# 1289076  ['Security Check', 'Passenger fails Security C...
# 1289077  ['Create purchase request', 'Place purchase or...
# 1289078  ['Create purchase request', 'Place purchase or...
# 1289079  ['Create purchase request', 'Place purchase or...
# 1289080  ['Create purchase request', 'Place purchase or...
#
#                                                     prefix  \
# 0                                    ['Add personal data']
# 1        ['Add personal data', 'Select necessary work e...
# 2        ['Add personal data', 'Select necessary work e...
# 3        ['Add personal data', 'Select necessary work e...
# 4                                    ['Add personal data']
# ...                                                    ...
# 1289076  ['Security Check', 'Passenger fails Security C...
# 1289077                        ['Create purchase request']
# 1289078  ['Create purchase request', 'Place purchase or...
# 1289079  ['Create purchase request', 'Place purchase or...
# 1289080  ['Create purchase request', 'Place purchase or...
#
#                                                 next  \
# 0                    Select necessary work equipment
# 1                             Procure work equipment
# 2        Set up access rights, hardware and software
# 3                                              [END]
# 4                    Select necessary work equipment
# ...                                              ...
# 1289076                                        [END]
# 1289077                         Place purchase order
# 1289078                                Receive goods
# 1289079                              Receive payment
# 1289080                                        [END]
#
#                                          unique_activities  \
# 0        {'Set up access rights, hardware and software'...
# 1        {'Set up access rights, hardware and software'...
# 2        {'Set up access rights, hardware and software'...
# 3        {'Set up access rights, hardware and software'...
# 4        {'Set up access rights, hardware and software'...
# ...                                                    ...
# 1289076  {'Passenger fails Security Check', 'Security C...
# 1289077  {'Receive goods', 'Receive payment', 'Place pu...
# 1289078  {'Receive goods', 'Receive payment', 'Place pu...
# 1289079  {'Receive goods', 'Receive payment', 'Place pu...
# 1289080  {'Receive goods', 'Receive payment', 'Place pu...
#
#                                                         id
# 0        e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 1        e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 2        e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 3        e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# 4        e8990a10f516495e89a1eabf9627b9e9_295ab34872b64...
# ...                                                    ...
# 1289076  1e07277a2ff0486cba1cd100be7b4a59_92f009351a754...
# 1289077  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 1289078  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 1289079  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
# 1289080  1e0d27c5c47f486f8b90cd517bf9449d_ae7a74f9ae4a4...
#
# [1289081 rows x 7 columns]
