# %%
import warnings
warnings.filterwarnings('ignore')
res_file = "../../data/results/mistralai-Mistral-7B-Instruct-v0.2next_activity_3,5_samples_per_class10000_runs5hing else._eval_results.csv"

import pandas as pd

# %%
df = pd.read_csv(res_file, sep=",")
df
# Out:
#    sample_size  run  precision mic  recall mic   f1 mic  precision mac  \
# 0            3    0        0.19115     0.19115  0.19115       0.175890
# 1            3    1        0.19295     0.19295  0.19295       0.182962
# 2            3    2        0.16210     0.16210  0.16210       0.152045
# 3            3    3        0.18415     0.18415  0.18415       0.152799
# 4            3    4        0.17905     0.17905  0.17905       0.186381
# 5            5    0        0.15125     0.15125  0.15125       0.133750
# 6            5    1        0.15135     0.15135  0.15135       0.136806
# 7            5    2        0.19550     0.19550  0.19550       0.194339
# 8            5    3        0.14980     0.14980  0.14980       0.148148
# 9            5    4        0.15040     0.15040  0.15040       0.145015
#
#    recall mac    f1 mac
# 0    0.261330  0.189355
# 1    0.248820  0.193661
# 2    0.214543  0.161054
# 3    0.234015  0.167004
# 4    0.249956  0.194889
# 5    0.201417  0.144225
# ...

# %%
df.groupby("sample_size").mean()
# Out:
#              run  precision mic  recall mic   f1 mic  precision mac  \
# sample_size
# 3            2.0        0.18188     0.18188  0.18188       0.170015
# 5            2.0        0.15966     0.15966  0.15966       0.151612
#
#              recall mac    f1 mac
# sample_size
# 3              0.241733  0.181192
# 5              0.215467  0.161253
